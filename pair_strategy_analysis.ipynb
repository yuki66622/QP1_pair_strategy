# %% [markdown]
# # Pair Strategy Project

# %% [markdown]
# ## 1. Project Objective

# %% [markdown]
# ## 2. Data Sources

# %% [markdown]
# ## 3. Methodology

# %% [markdown]
# ## 4. Results

# %% [markdown]
# ## 5. Conclusions
